# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# Heart Disease Project

# %%
 import pandas as pd

# %%
df = pd.read_csv('43 - heart-disease.csv')

# %% [markdown]
# Here Is the data for heart disease

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
df.target.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='target'>

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0037-90E0
#
#  Directory of C:\Users\aayus\Desktop\sample_project_1
#
# 02/25/2023  03:54 PM    <DIR>          .
# 02/25/2023  03:33 PM    <DIR>          ..
# 02/24/2023  05:03 PM    <DIR>          .ipynb_checkpoints
# 02/24/2023  05:00 PM            11,328 43 - heart-disease.csv
# 02/24/2023  04:28 PM    <DIR>          env
# 02/25/2023  03:54 PM            15,748 My_First_Project_In_Data_Science.ipynb
#                2 File(s)         27,076 bytes
#                4 Dir(s)  77,456,744,448 bytes free

# %% [markdown]
# ## Getting Started

# %% [markdown]
# ## 1. Problem Defination
# Predicting the Heart deisease
