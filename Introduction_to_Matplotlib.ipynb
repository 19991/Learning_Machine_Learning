# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4,5,6,6])

# %%
x= [1,2,3,4,5,6,7]
y = [8,9,10,11,12,13,14]
plt.plot(x,y);

# %%
# 1st Method 
fig = plt.figure() #creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %% [markdown]
# ## 3rd Method (recommended)

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,250,300,350,500]); #add some data

# %% [markdown]
# ## Matplotlib example WorkFlow

# %%
# 0. Import matplotlib and get it ready for ploting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data 
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize = (10,10)) # (width,Height)

# 3. Plot data

ax.plot(x,y)

# 4. Customize plot

ax.set(title = 'simple plot',
      xlabel='x lable',
      ylabel='y lable')

# 5. Save & show (you save the whole figure to the mentioned path)
fig.savefig("C:/Users/aayus/OneDrive/Pictures/Pratice_Data/sample_plot")

# %% [markdown]
# ## Making Figure with NumPy array
#
# We want:
#
# * Line Plot
# * Scatter plot
# * Bar plot
# * Subplots

# %%
import numpy as np 


#create some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data and create the line plot
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
#use same data to make scatter plot

fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot 
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary 
nut_butter_price = {"almond butter":10,
                   "Peanut butter":8,
                   "Cashew butter":12}
fig, ax = plt.subplots()
ax.bar(nut_butter_price.keys(), nut_butter_price.values())
ax.set(title="Aayush Nut Butter Store",
       ylabel="Price ($)"
      );

# %%
# Make some data for histogram
x = np.random.randn(10000)
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([   4.,   70.,  473., 1504., 2779., 2841., 1685.,  563.,   76.,
#            5.]),
#  array([-4.00227592, -3.21212307, -2.42197022, -1.63181737, -0.84166452,
#         -0.05151167,  0.73864118,  1.52879403,  2.31894687,  3.10909972,
#          3.89925257]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Two options for subplots

# %%
#subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows =2,
                                         ncols = 2,
                                         figsize = (10,5))
# Plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_price.keys(), nut_butter_price.values());
ax4.hist(np.random.randn(10000));

# %%
#Subplot option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize= (10,5))
# Plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_price.keys(), nut_butter_price.values());
ax[1,1].hist(np.random.randn(10000));

# %% [markdown]
# ## plotting from pandas dataframes

# %%
import pandas as pd

# %%
# Make a DataFram
car_sale = pd.read_csv("car-sales.csv")
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sale["Price"] = car_sale["Price"].str.replace('[\$\,\.]','')
car_sale
# Out:
# C:\Users\aayus\AppData\Local\Temp\ipykernel_16260\2943853113.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sale["Price"] = car_sale["Price"].str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Remove the last two zero

car_sale['Price'] = car_sale['Price'].str[:-2]
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sale['Sale_date'] = pd.date_range('1/1/2022', periods=len(car_sale))
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sale['Total Sales'] = car_sale['Price'].astype(int).cumsum()
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
#Lets plot the total sales

car_sale.plot(x='Sale_date',y ='Total Sales');

# %%
car_sale['Price'] = car_sale['Price'].astype(int)
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
car_sale.plot(x = 'Odometer (KM)', y = 'Price' , kind= 'scatter');

# %%
car_sale.plot(x='Make',y='Price', kind = 'bar');

# %% [markdown]
# ##  Use Another DataFrame for Plotting

# %%
heart_disease = pd.read_csv('43 - heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#create a hist for age
heart_disease['age'].plot.hist(bins = 10);

# %%
heart_disease.plot.hist(figsize=(10,30),subplots= True);

# %%
over_50 = heart_disease[heart_disease['age']>50]
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax = ax);

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x = over_50['age'],
                    y = over_50['chol'],
                    c = over_50['target'])
ax.set(title='Heart Disease and cholestrol level',
      xlabel='Age',
      ylabel='Cholestrol')
ax.legend(*scatter.legend_elements(), title = 'Target')

ax.axhline(over_50['chol'].mean(),
          linestyle = '--');

# %%
fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize= (10,10))
scatter = ax0.scatter(x=over_50['age'],
                      y= over_50['chol'],
                      c= over_50['target'])
ax0.set(title = 'Heart disease',
       xlabel='Age',
       ylabel ='Cholestorl')
ax0.legend(*scatter.legend_elements(),title= 'Target')

ax0.axhline(y= over_50['chol'].mean(),
           linestyle = '--');




scatter = ax1.scatter(x=over_50['age'],
                      y= over_50['thalach'],
                      c= over_50['target'])
ax1.set(title = 'Heart disease and Thalach',
       xlabel='Age',
       ylabel ='thalach')
ax1.legend(*scatter.legend_elements(),title= 'Target')

ax1.axhline(y= over_50['thalach'].mean(),
           linestyle = '--')

fig.suptitle("Heart Disease Analysis", fontsize =16,fontweight= 'bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
fig.savefig('Heart Disease Analysis Pic Saved with code')
